# %% [markdown]
# # Creating a Multilingual Chatbot with Only 9 Lines of Code Using bigscience/bloomz-1b1

# %%
# Install the Hugging Face library
# !pip install transformers

# Load the bigscience/bloomz-1b1 model and tokenizer from the Hugging Face library
from transformers import AutoModelWithLMHead, AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("bigscience/bloomz-1b1")
model = AutoModelWithLMHead.from_pretrained("bigscience/bloomz-1b1")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 32.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 51.4 MB/s eta 0:00:00
# ...
# /usr/local/lib/python3.8/dist-packages/transformers/models/auto/modeling_auto.py:1248: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   warnings.warn(
# ...

# %%
# Get the model's response to user input text
input_text = "why the sky is blue?"
input_ids = tokenizer.encode(input_text, return_tensors='pt')
outputs = model.generate(input_ids)

# Decode the model's response and display it on the screen
response = tokenizer.decode(outputs[0])
print(response)
# Out:
# why the sky is blue? The sky is blue because it is blue.</s>

# %%
# Get the model's response to user input text
# why the sky is blue?
input_text = "Por que el cielo es azul?"
input_ids = tokenizer.encode(input_text, return_tensors='pt')
outputs = model.generate(input_ids)

# Decode the model's response and display it on the screen
response = tokenizer.decode(outputs[0])
print(response)
# Out:
# Por que el cielo es azul? El cielo es azul porque es un color que se encuentra en la

# %%
# Get the model's response to user input text
# what is financial freedom?
input_text = "什么是财富自由?"
input_ids = tokenizer.encode(input_text, return_tensors='pt')
outputs = model.generate(input_ids)

# Decode the model's response and display it on the screen
response = tokenizer.decode(outputs[0])
print(response)
# Out:
# 什么是财富自由? 自由地选择自己的生活方式，而不受他人影响。</s>
